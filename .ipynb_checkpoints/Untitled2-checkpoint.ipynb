# %%
import pandas_datareader.data as web # pandas-datareaderのインポート

# df = web.DataReader('ティッカー','エンドポイント',start='hoge',end='hoge',api_key='hoge')

# %%
df=web.DataReader('AAPL',api)

# %%
aapl = Ticker('aapl')

# %%
[i for i in Ticker.__dict__.keys() 
 if "_" not in i[:2] and i not in ["option_chain", "history", "symbols"]]
# Out:
# ['all_modules',
#  'get_modules',
#  'asset_profile',
#  'calendar_events',
#  'earnings',
#  'earnings_trend',
#  'esg_scores',
#  'financial_data',
#  'news',
#  'index_trend',
#  'industry_trend',
#  'key_stats',
#  'major_holders',
#  'page_views',
#  'price',
#  'quote_type',
#  'quotes',
#  'recommendations',
#  'share_purchase_activity',
#  'summary_detail',
#  'summary_profile',
#  'technical_insights',
#  'all_financial_data',
#  'get_financial_data',
#  'corporate_events',
#  'corporate_guidance',
#  'valuation_measures',
#  'balance_sheet',
#  'cash_flow',
#  'company_officers',
#  'earning_history',
#  'fund_ownership',
#  'grading_history',
#  'income_statement',
#  'insider_holders',
#  'insider_transactions',
#  'institution_ownership',
#  'recommendation_trend',
#  'sec_filings',
#  'fund_bond_holdings',
#  'fund_category_holdings',
#  'fund_equity_holdings',
#  'fund_performance',
#  'fund_profile',
#  'fund_holding_info',
#  'fund_top_holdings',
# ...

# %% [markdown]
# - all_modules：全データ
# - get_modules：？
# - asset_profile：会社基本情報
# - calendar_events：決算日
# - earnings：予想と実績の収益・利益（直近のみ？）
# - earnings_trend：earningsの未来の分も見れる？
# - esg_scores：ESGスコア（投資先の選定基準）

# %%
aapl.financial_data
# Out:
# {'aapl': {'maxAge': 86400,
#   'currentPrice': 179.42,
#   'targetHighPrice': 210.0,
#   'targetLowPrice': 128.01,
#   'targetMeanPrice': 174.93,
#   'targetMedianPrice': 174.5,
#   'recommendationMean': 1.8,
#   'recommendationKey': 'buy',
#   'numberOfAnalystOpinions': 42,
#   'totalCash': 62639001600,
#   'totalCashPerShare': 3.818,
#   'ebitda': 120233000960,
#   'totalDebt': 136521998336,
#   'quickRatio': 0.91,
#   'currentRatio': 1.075,
#   'totalRevenue': 365817004032,
#   'debtToEquity': 216.392,
#   'revenuePerShare': 21.904,
#   'returnOnAssets': 0.20179,
#   'returnOnEquity': 1.47443,
#   'grossProfits': 152836000000,
#   'freeCashflow': 73295003648,
#   'operatingCashflow': 104037998592,
#   'earningsGrowth': 0.662,
#   'revenueGrowth': 0.288,
#   'grossMargins': 0.41779,
#   'ebitdaMargins': 0.32867,
#   'operatingMargins': 0.29782,
#   'profitMargins': 0.25882,
#   'financialCurrency': 'USD'}}

# %%
# 企業情報（会社の基本情報や役員情報）
se.history(period='max')['close'].plot(figsize=(16, 9))
